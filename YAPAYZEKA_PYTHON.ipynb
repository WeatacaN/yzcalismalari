# %%
print("Merhaba, İGÜ - YAPAY ZEKA geliştirilmesi için kullanılacak kütüphaneler")
# Out:
# Merhaba, İGÜ - YAPAY ZEKA geliştirilmesi için kullanılacak kütüphaneler

# %%
import sys
print(sys.version)
# Out:
# 3.10.12 (main, Sep 11 2024, 15:47:36) [GCC 11.4.0]

# %%
from google.colab import drive # google colab - drive bağlantısı
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os

os.chdir('/content/drive/My Drive/YAPAYZEKA')

# !pwd # bize kodun çıktısı dosya yolu olarak veren kod blogdur
# Out:
# /content/drive/My Drive/YAPAYZEKA

# %% [markdown]
# PANDAS Kulanım alanları:
#
# 1.Veri yapıları
#
# 2.Veri Okuma ve Yazma
#
# 3.Veri Seçme,Birleştirme,Dönüştürme,Temizleme ve Filtreleme
#
# 4.Veri Analizi
#
# 5.İstatiksel Hesaplama
#
# Pandas Veri Analizi Fonksiyonları ->
#
# 1.df['Not'].min() # En düşük değeri bulur.
#
# 2.df['Not'].mean() # Ortalama değeri hesaplar.
#
# 3.df['Not'].median() # Medyanı bulur.
#
# 4.df['Not'].std() # Standart sapmayı hesaplar.
#
# 5.df['Not'].sum() # Toplam değeri bulur.
#
# 6.df.describe() # Veri setinin özet istatisklerini verir.

# %%
import pandas as pd
# Yiğit'in ders ve not bilgileri
data = {'Ders': ['Algoritma', 'BilgisayarProgramlama', 'Elektronik-2', 'AviyonikSistemler'],
        'Not': [95, 100, 65, 90]}

#Veriyi bir DataFrame'e dönüştürür
df = pd.DataFrame(data)

#En yüksek notu bul
en_yuksek_not = df['Not'].max()
print("En yüksek not:", en_yuksek_not)

# Ortalama notu hesapla
ortalama_not = df['Not'].mean()
print("Ortalama not:", ortalama_not)
print(df.describe())
# Out:
# En yüksek not: 100
# Ortalama not: 87.5
#               Not
# count    4.000000
# mean    87.500000
# std     15.545632
# min     65.000000
# 25%     83.750000
# 50%     92.500000
# 75%     96.250000
# max    100.000000

# %% [markdown]
# NUMPY Kullanım Alanları:
# NUMPY FONKSİYONLARI

# %%
import numpy as np

# Rastgele tanımlanan değerler - sıralaması olmayan
dizi = np.array([1, -55, 9, -23, 13, -21, 23, 37, 29, -6])

# Dizinin Ortalama sonuc
ortalama = np.mean(dizi)
print("Ortalama:", ortalama)

# Dizinin standart sapma
std_sapma = np.std(dizi)
print("Standart Sapma:", std_sapma)

# Dizinin mutlağını al
mutlak_veriler = np.abs(dizi)
print("Mutlak Deger Cıktısı:", mutlak_veriler)
# Out:
# Ortalama: 0.7
# Standart Sapma: 26.487921775783015
# Mutlak Deger Cıktısı: [ 1 55  9 23 13 21 23 37 29  6]

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 10, 100)
y = np.sin(x)

plt.plot(x, y)
plt.title('Sinüs Grafiği')
plt.xlabel('X Ekseni')
plt.ylabel('Y Ekseni')
plt.grid(True) # Arkasına kare gelmesin istiyorsan False
plt.show()

# %%
import matplotlib.pyplot as plt

# Yıllara göre satışlar
yillar = [2018, 2019, 2020, 2021, 2022]
satislar = [150, 200, 20, -225, 14]

# Satış grafiğini çiz
plt.plot(yillar, satislar, marker='o')

# Örnek başlıkları
plt.title("Yıllara Göre Satışlar")
plt.xlabel("Yıllar")
plt.ylabel("Satış Miktarı")

# Grafiği göster
plt.show()
